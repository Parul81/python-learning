# %% [markdown]
# # Working on Real Project With Python

# %% [markdown]
# # (A Part of Big Data Analysis)

# %% [markdown]
# # The Weather Dataset

# %%
Here, The Weather Dataset is a time-series data set with per_hour information about the weather conditions at a particular 
#location.It records Temperature,Dew Point Temperature ,Relative Humidity,Wind Speed,Visibiliy,Pressure and conditions.

This data is available as a CSV file.We are going to analyze this data set using the Pandas DataFrame.

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\parul\Downloads\archive\weatherHistory.csv")

# %%
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# # How to Analyze DataFrames ?

# %% [markdown]
# # .head()

# %%
# It shows the first N rows in the data (by default, N=5).

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %% [markdown]
# # .shape

# %%
# It shows the total no. of rows and no. of columns of the dataframe

# %%
data.shape
# Out:
# (96453, 12)

# %% [markdown]
# # .index

# %%
# This attribute provides the index of the dataframe

# %%
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %% [markdown]
# # .columns

# %%
# It shows the name of each column

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %% [markdown]
# # .dtypes

# %%
# It shows the data-type of each column

# %%
data.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %% [markdown]
# # .unique()

# %%
# In a column, it shows all the unique values. It can be applied on a single column only, not on the whole dataframe.

# %%
data["Summary"].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %% [markdown]
# # .nunique()

# %%
# It shows the total no. of unique values in each column. It can be applied on a single column as well as on the whole dataframe.

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %% [markdown]
# # .Count

# %%
# It shows the total no. of non-null values in each column. It can be applied on a single column as well as on the whole dataframe.

# %%
data.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %% [markdown]
# # value_counts

# %%
# In a column, it shows all the unique values with their count. It can be applied on a single column only.

# %%
data["Summary"].value_counts()
# Out:
# Summary
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %% [markdown]
# # info()

# %%
# Provides basic information about the dataframe.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# # Q. 1)  Find all the unique 'Wind Speed' values in the data.

# %%
data.head(5)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
data["Wind Speed (km/h)"].nunique()
# Out:
# 2484

# %%
data["Wind Speed (km/h)"].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %% [markdown]
# # Q. 2)  Find the number of times when the 'Weather is exactly Clear'.

# %%
data.head(4)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# ...

# %%
#Filtering
dt=data[data["Summary"]=="Clear"]
dt
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
dt.count()
# Out:
# Formatted Date              10890
# Summary                     10890
# Precip Type                 10763
# Temperature (C)             10890
# Apparent Temperature (C)    10890
# Humidity                    10890
# Wind Speed (km/h)           10890
# Wind Bearing (degrees)      10890
# Visibility (km)             10890
# Loud Cover                  10890
# Pressure (millibars)        10890
# Daily Summary               10890
# dtype: int64

# %%
#value_counts:-

data.Summary.value_counts()
# Out:
# Summary
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
#Groupby():-

data.groupby("Summary").get_group("Clear")
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [markdown]
# # Q. 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
data.head(6)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# 5                  7.111111      0.85            13.9587
#
# ...

# %%
data[data["Wind Speed (km/h)"]==4]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
data[data["Wind Speed (km/h)"]==4].count()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# # Q. 4) Find out all the Null Values in the data.

# %%
data.isnull()
# Out:
#        Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0               False    False        False            False
# 1               False    False        False            False
# 2               False    False        False            False
# 3               False    False        False            False
# 4               False    False        False            False
# ...               ...      ...          ...              ...
# 96448           False    False        False            False
# 96449           False    False        False            False
# 96450           False    False        False            False
# 96451           False    False        False            False
# 96452           False    False        False            False
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                         False     False              False
# 1                         False     False              False
# ...

# %%
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %% [markdown]
# # Q. 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data.rename(columns={"Summary":"Weather"})
# Out:
#                       Formatted Date        Weather Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data.rename(columns={"Summary":"Weather"},inplace=True)

# %%
data.head()
# Out:
#                   Formatted Date        Weather Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %% [markdown]
# # Q. 6) What is the mean 'Visibility' ?

# %%
data["Visibility (km)"].mean()
# Out:
# 10.347324929240148

# %% [markdown]
# # Q. 7) What is the Standard Deviation of 'Pressure'  in this data?

# %%
data["Pressure (millibars)"].std()
# Out:
# 116.96990568258147

# %% [markdown]
# # Q. 8) What is the Variance of 'Relative Humidity' in this data ?

# %%
data["Apparent Temperature (C)"].var()
# Out:
# 114.42254413028867

# %% [markdown]
# # Q. 9) Find all instances when 'Snow' was recorded.

# %%
# Value_counts():-

data.head(2)
data["Weather"].value_counts()
# Out:
# Weather
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
# Filtering:- 

data[data["Weather"]=="Snow"]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Weather, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
data[data["Weather"]=="Snow"].count()
# Out:
# Formatted Date              0
# Weather                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
#str.contains :-

data[data["Weather"].str.contains("Snow")]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Weather, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
data[data["Weather"].str.contains("Snow")].count()
# Out:
# Formatted Date              0
# Weather                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# # Q. 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
data.head(2)
# Out:
#                   Formatted Date        Weather Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[(data["Wind Speed (km/h)"]>24) & (data["Visibility (km)"]==25)]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Weather, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %% [markdown]
# # Q. 11) What is the Mean value of each column against each 'Weather' ?

# %%
data.head(4)
# Out:
#                   Formatted Date        Weather Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# ...

# %%
data.groupby("Visibility (km)").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %% [markdown]
# # Q. 12) What is the Minimum & Maximum value of each column against each 'Weather'?

# %%
data.head(3)
# Out:
#                   Formatted Date        Weather Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# ...

# %%
data.groupby("Pressure (millibars)").min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %%
data.groupby("Pressure (millibars)").max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...

# %% [markdown]
# # Q. 13) Show all the Records where Weather Condition is Fog.

# %%
data.head(2)
# Out:
#                   Formatted Date        Weather Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[data["Weather"]=="Fog"]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Weather, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
data[data["Weather"]=="Fog"].count()
# Out:
# Formatted Date              0
# Weather                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# # Q. 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
data[(data["Weather"]=="Clear") | (data["Visibility (km)"]>40)]
# Out:
#                       Formatted Date Weather Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [markdown]
# # Q. 15) Find all instances when :
# # A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# # or
# # B. 'Visibility is above 40'

# %%
data[(data["Weather"]=="Clear") & (data["Humidity"]>50) | (data["Visibility (km)"]>40)]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Weather, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
data
# Out:
#                       Formatted Date        Weather Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data1=data[(data["Weather"]=="Clear") & (data["Pressure (millibars)"]>50) | (data["Visibility (km)"]>40)].head(10)
data1.plot.bar(x="Weather",y="Pressure (millibars)")
# Out:
# <Axes: xlabel='Weather'>

# %%
data
# Out:
#                       Formatted Date        Weather Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...
