# %% [markdown]
# # DAY-1

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
s = pd.Series()
print(s)
# Out:
# Series([], dtype: object)

# %%
import pandas as pd
s1 = pd.Series(["p","y","t","h","o","n"])
print(s1,type(s1))
# Out:
# 0    p
# 1    y
# 2    t
# 3    h
# 4    o
# 5    n
# dtype: object <class 'pandas.core.series.Series'>

# %%
import pandas as pd
s1 = pd.Series(["p","y","t","h","o","n"],index=[5,10,15,20,25,30])
print(s1,type(s1))
# Out:
# 5     p
# 10    y
# 15    t
# 20    h
# 25    o
# 30    n
# dtype: object <class 'pandas.core.series.Series'>

# %%
import pandas as pd
import numpy as np
ar=np.array([45,55,60,77])
s2 = pd.Series(ar)
print(s2)
# Out:
# 0    45
# 1    55
# 2    60
# 3    77
# dtype: int32

# %%
import numpy as np
import pandas as pd
ar = np.array([[45,55,60,77]])
s2 = pd.Series(ar)
print(s2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 import pandas as pd
#       3 ar = np.array([[45,55,60,77]])
# ----> 4 s2 = pd.Series(ar)
#       5 print(s2)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:512, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     510         data = data.copy()
#     511 else:
# --> 512     data = sanitize_array(data, index, dtype, copy)
#     514     manager = get_option("mode.data_manager")
#     515     if manager == "block":
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\construction.py:658, in sanitize_array(data, index, dtype, copy, allow_2d)
#     655             subarr = cast(np.ndarray, subarr)
#     656             subarr = maybe_infer_to_datetimelike(subarr)
# --> 658 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
# ...

# %%
import pandas as pd
s1 = pd.Series(["p","y","t","h","o","n"],index=[5,10,15,20,25,30])
print(s1,type(s1))
# Out:
# 5     p
# 10    y
# 15    t
# 20    h
# 25    o
# 30    n
# dtype: object <class 'pandas.core.series.Series'>

# %%
import pandas as pd
s1 = pd.Series({"p","y","t","h","o","n"},index=[5,10,15,20,25,30])
print(s1,type(s1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 s1 = pd.Series({"p","y","t","h","o","n"},index=[5,10,15,20,25,30])
#       3 print(s1,type(s1))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:512, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     510         data = data.copy()
#     511 else:
# --> 512     data = sanitize_array(data, index, dtype, copy)
#     514     manager = get_option("mode.data_manager")
#     515     if manager == "block":
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\construction.py:641, in sanitize_array(data, index, dtype, copy, allow_2d)
#     632     return sanitize_array(
#     633         data,
#     634         index=index,
#    (...)
#     637         allow_2d=allow_2d,
#     638     )
#     640 else:
# ...

# %%
import pandas as pd
s4 = pd.Series({"Name":"Mohan","Age":24})

# %%
s4
# Out:
# Name    Mohan
# Age        24
# dtype: object

# %%
import pandas as pd
s4 = pd.Series({"Name":["Mohan","Rohan"],"Age":[24,25]})

# %%
s4
# Out:
# Name    [Mohan, Rohan]
# Age           [24, 25]
# dtype: object

# %%
import pandas as pd
s1 = pd.Series(("p","y","t","h","o","n"),index=[5,10,15,20,25,30])
print(s1,type(s1))
# Out:
# 5     p
# 10    y
# 15    t
# 20    h
# 25    o
# 30    n
# dtype: object <class 'pandas.core.series.Series'>

# %%
s1
# Out:
# 5     p
# 10    y
# 15    t
# 20    h
# 25    o
# 30    n
# dtype: object

# %%
s1[25]
# Out:
# 'o'

# %%
s1[30]
# Out:
# 'n'

# %%
import pandas as pd
s1 = pd.Series([45,55,66,77])
s2 = pd.Series([4.5,6.6,7.7],index=["a","b","c"])

# %%
s1
# Out:
# 0    45
# 1    55
# 2    66
# 3    77
# dtype: int64

# %%
s2
# Out:
# a    4.5
# b    6.6
# c    7.7
# dtype: float64

# %%
print(s1.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(s1.values)
# Out:
# [45 55 66 77]

# %%
print(s2.index)
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
print(s2.values)
# Out:
# [4.5 6.6 7.7]

# %%
print(s1.dtype)
# Out:
# int64

# %%
print(s2.dtype)
# Out:
# float64

# %%
print(s1.size)
# Out:
# 4

# %%
print(s2.size)
# Out:
# 3

# %%
s1.itemsize
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8212\3541679674.py in ?()
# ----> 1 s1.itemsize
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'itemsize'

# %%
print(s1.ndim)
# Out:
# 1

# %%
print(s.ndim)
# Out:
# 1

# %%
print(s1.shape)
# Out:
# (4,)

# %%
print(s2.shape)
# Out:
# (3,)

# %%
print(s1.nbytes)
# Out:
# 32

# %%
print(s2.nbytes)
# Out:
# 24

# %%
a=pd.Series([4.5,6.6,np.NaN])
b=pd.Series([7,8,89])
c=pd.Series()

# %%
a
# Out:
# 0    4.5
# 1    6.6
# 2    NaN
# dtype: float64

# %%
b
# Out:
# 0     7
# 1     8
# 2    89
# dtype: int64

# %%
c
# Out:
# Series([], dtype: object)

# %%
print(a.empty)
# Out:
# False

# %%
print(b.empty)
# Out:
# False

# %%
print(c.empty)
# Out:
# True

# %%
print(a.hasnans)
# Out:
# True

# %%
print(b.hasnans)
# Out:
# False

# %%
print(c.hasnans)
# Out:
# False

# %%
print(len(a))
# Out:
# 3

# %%
len(b)
# Out:
# 3

# %%
len(c)
# Out:
# 0

# %%
a.count
# Out:
# <bound method Series.count of 0    4.5
# 1    6.6
# 2    NaN
# dtype: float64>

# %%
import numpy as np
import pandas as pd
s1 = pd.Series(["Mango","Kiwi","Apple","Grappes",np.nan])
s1
# Out:
# 0      Mango
# 1       Kiwi
# 2      Apple
# 3    Grappes
# 4        NaN
# dtype: object

# %%
s1.map({"Mango":"Carrot"})
# Out:
# 0    Carrot
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# dtype: object

# %%
s1.map("I like {}".format,na_action="ignore")
# Out:
# 0      I like Mango
# 1       I like Kiwi
# 2      I like Apple
# 3    I like Grappes
# 4               NaN
# dtype: object

# %%
s2 = pd.Series([45,55,66,77,np.nan,77])

# %%
s2
# Out:
# 0    45.0
# 1    55.0
# 2    66.0
# 3    77.0
# 4     NaN
# 5    77.0
# dtype: float64

# %%
np.std(s2)
# Out:
# 12.521980673998822

# %%
s3 = pd.Series(["a","b","c","d"],name="x")
s3
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# Name: x, dtype: object

# %%
print(s3,type(s3))
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# Name: x, dtype: object <class 'pandas.core.series.Series'>

# %%
s3.to_frame
# Out:
# <bound method Series.to_frame of 0    a
# 1    b
# 2    c
# 3    d
# Name: x, dtype: object>

# %%
s3.to_frame()
# Out:
#    x
# 0  a
# 1  b
# 2  c
# 3  d

# %%
s4 = pd.Series([22,12,12,13,16,45,22,23,np.nan])
s4
# Out:
# 0    22.0
# 1    12.0
# 2    12.0
# 3    13.0
# 4    16.0
# 5    45.0
# 6    22.0
# 7    23.0
# 8     NaN
# dtype: float64

# %%
print(s4,type(s4))
# Out:
# 0    22.0
# 1    12.0
# 2    12.0
# 3    13.0
# 4    16.0
# 5    45.0
# 6    22.0
# 7    23.0
# 8     NaN
# dtype: float64 <class 'pandas.core.series.Series'>

# %%
s4.value_counts()
# Out:
# 22.0    2
# 12.0    2
# 13.0    1
# 16.0    1
# 45.0    1
# 23.0    1
# Name: count, dtype: int64

# %%
s4.value_counts(normalize = True)
# Out:
# 22.0    0.250
# 12.0    0.250
# 13.0    0.125
# 16.0    0.125
# 45.0    0.125
# 23.0    0.125
# Name: proportion, dtype: float64

# %%
s4.value_counts(bins=2)
# Out:
# (11.966000000000001, 28.5]    7
# (28.5, 45.0]                  1
# Name: count, dtype: int64

# %%
s4.value_counts(dropna = False)
# Out:
# 22.0    2
# 12.0    2
# 13.0    1
# 16.0    1
# 45.0    1
# 23.0    1
# NaN     1
# Name: count, dtype: int64

# %%
s5 = pd.Series(5,index=[0,1,2,3,4])

# %%
s5
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
s3
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# Name: x, dtype: object

# %%
s3.to_dict()
# Out:
# {0: 'a', 1: 'b', 2: 'c', 3: 'd'}

# %%
s3.to_list()
# Out:
# ['a', 'b', 'c', 'd']

# %%
import pandas as pd
df = pd.DataFrame([4,5,6,78,88,99])
df
# Out:
#     0
# 0   4
# 1   5
# 2   6
# 3  78
# 4  88
# 5  99

# %%
import pandas as pd
df = pd.DataFrame([4,5,6,78,88,99],index=["a","b","c","d","e","f"])
df
# Out:
#     0
# a   4
# b   5
# c   6
# d  78
# e  88
# f  99

# %%
import pandas as pd
df1 = pd.DataFrame(pd.Series([4,5,6,78,88,99],index=["a","b","c","d","e","f"]))
df1
# Out:
#     0
# a   4
# b   5
# c   6
# d  78
# e  88
# f  99

# %%
s1 = pd.Series([4,5,6,7,8],index=["a","b","c","d","e"])
s2 = pd.Series([22,55,66],index=["a","b","c"])

# %%
import pandas as pd
df1 = pd.DataFrame([s1,s2])
df1
# Out:
#       a     b     c    d    e
# 0   4.0   5.0   6.0  7.0  8.0
# 1  22.0  55.0  66.0  NaN  NaN

# %%
import pandas as pd
a1 = [4,5,6,78,88,99]
a2 = [100,200,300]
df = pd.DataFrame(a1,a2)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 4
#       2 a1 = [4,5,6,78,88,99]
#       3 a2 = [100,200,300]
# ----> 4 df = pd.DataFrame(a1,a2)
#       5 df
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:822, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     814         mgr = arrays_to_mgr(
#     815             arrays,
#     816             columns,
#    (...)
#     819             typ=manager,
#     820         )
#     821     else:
# --> 822         mgr = ndarray_to_mgr(
#     823             data,
#     824             index,
#     825             columns,
#     826             dtype=dtype,
#     827             copy=copy,
#     828             typ=manager,
#     829         )
#     830 else:
#     831     mgr = dict_to_mgr(
#     832         {},
#     833         index,
#    (...)
# ...

# %%
import pandas as pd
df = pd.DataFrame({"s1":pd.Series([4,5,6,7,8],index=["a","b","c","d","e"]),
"s2":pd.Series([22,55,66],index=["a","b","c"])})
df
# Out:
#    s1    s2
# a   4  22.0
# b   5  55.0
# c   6  66.0
# d   7   NaN
# e   8   NaN

# %%
df = pd.DataFrame({"s1":[4,5,6,7,8],"s2":[77,88,99,100,102]})

# %%
df
# Out:
#    s1   s2
# 0   4   77
# 1   5   88
# 2   6   99
# 3   7  100
# 4   8  102

# %%
df["s3"]=[12,23,45,12,25]

# %%
df
# Out:
#    s1   s2  s3
# 0   4   77  12
# 1   5   88  23
# 2   6   99  45
# 3   7  100  12
# 4   8  102  25

# %%
del df["s3"]

# %%
df
# Out:
#    s1   s2
# 0   4   77
# 1   5   88
# 2   6   99
# 3   7  100
# 4   8  102

# %%
df.pop("s2")
# Out:
# 0     77
# 1     88
# 2     99
# 3    100
# 4    102
# Name: s2, dtype: int64

# %%
df
# Out:
#    s1
# 0   4
# 1   5
# 2   6
# 3   7
# 4   8

# %%
df.pop("s1")
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# Name: s1, dtype: int64

# %%
print(df,type(df))
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4] <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.DataFrame({"s1":[4,5,6,7,8],"s2":[77,88,99,100,101]})

# %%
df
# Out:
#    s1   s2
# 0   4   77
# 1   5   88
# 2   6   99
# 3   7  100
# 4   8  101

# %%
del df["s2"]

# %%
df
# Out:
#    s1
# 0   4
# 1   5
# 2   6
# 3   7
# 4   8

# %%
del df["s1"]

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
del df

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame({"s1":[4,5,6,7,8],"s2":[77,88,99,100,101]})

# %%
df
# Out:
#    s1   s2
# 0   4   77
# 1   5   88
# 2   6   99
# 3   7  100
# 4   8  101

# %%
df["s2"][3]
# Out:
# 100

# %%
df["s1"][2]
# Out:
# 6

# %%
df
# Out:
#    s1   s2
# 0   4   77
# 1   5   88
# 2   6   99
# 3   7  100
# 4   8  101

# %%
df["s1"][4]=12

# %%
df
# Out:
#    s1   s2
# 0   4   77
# 1   5   88
# 2   6   99
# 3   7  100
# 4  12  101

# %%
df.loc[0:4]
# Out:
#    s1   s2
# 0   4   77
# 1   5   88
# 2   6   99
# 3   7  100
# 4  12  101

# %%
df[1:10:2]
# Out:
#    s1   s2
# 1   5   88
# 3   7  100

# %%
df[1:6:1,0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(1, 6, 1), slice(0, 2, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 df[1:6:1,0:2]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# ...

# %%
df.loc[0:5:2]
# Out:
#    s1   s2
# 0   4   77
# 2   6   99
# 4  12  101

# %%
df
# Out:
#    s1   s2
# 0   4   77
# 1   5   88
# 2   6   99
# 3   7  100
# 4  12  101

# %%
df[0:10:2,0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(0, 10, 2), slice(0, 3, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 df[0:10:2,0:3]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# ...

# %% [markdown]
# # DAY-2

# %%
import pandas as pd
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_Indian_films_of_2024")

# %%
df = df[1]

# %%
df
# Out:
#    Rank           Title                                 Production company  \
# 0     1        Hanu-Man                           Prime Show Entertainment
# 1     2         Fighter                  Viacom18 Studios Marflix Pictures
# 2     3  Manjummel Boys                                       Parava Films
# 3     4        Shaitaan             Jio StudiosDevgn FilmsPanorama Studios
# 4     5   Guntur Kaaram                        Haarika & Hassine Creations
# 5     6   The Goat Life  Visual Romance Jet Media Production Alta Globa...
# 6     7            Crew  Balaji Motion Pictures Anil Kapoor Films & Com...
# 7     8        Aavesham  Anwar Rasheed Entertainments Fahadh Faasil and...
# 8     9         Premalu                                    Bhavana Studios
# 9    10    Tillu Square        Sithara Entertainments Fortune Four Cinemas
#
#                Distributor(s)   Language                Worldwide gross  \
# ...

# %%
df.iloc[0:50:2,0:5:2]
# Out:
#    Rank                                 Production company   Language
# 0     1                           Prime Show Entertainment     Telugu
# 2     3                                       Parava Films  Malayalam
# 4     5                        Haarika & Hassine Creations     Telugu
# 6     7  Balaji Motion Pictures Anil Kapoor Films & Com...      Hindi
# 8     9                                    Bhavana Studios  Malayalam

# %%
df.loc[0:50:2,["Rank","Language"]]
# Out:
#    Rank   Language
# 0     1     Telugu
# 2     3  Malayalam
# 4     5     Telugu
# 6     7      Hindi
# 8     9  Malayalam

# %%
df=pd.read_csv("C:\\Users\\parul\\Desktop\\Popular_Spotify_Songs.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 df=pd.read_csv("C:\\Users\\parul\\Desktop\\Popular_Spotify_Songs.csv")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.DataFrame({"X":[12,23,45,26],"Y":[14,25,36,16]})
df1 = pd.DataFrame({"X":[22,33,44],"Y":[12,21,36],"Z":[12,23,89]})

# %%
df
# Out:
#     X   Y
# 0  12  14
# 1  23  25
# 2  45  36
# 3  26  16

# %%
df1
# Out:
#     X   Y   Z
# 0  22  12  12
# 1  33  21  23
# 2  44  36  89

# %%
k = pd.Series([12,23,44])

# %%
k
# Out:
# 0    12
# 1    23
# 2    44
# dtype: int64

# %%
type(k[0])
# Out:
# numpy.int64

# %%
type(k[2])
# Out:
# numpy.int64

# %%
df1 = k.to_frame()

# %%
df1.describe()
# Out:
#                0
# count   3.000000
# mean   26.333333
# std    16.258331
# min    12.000000
# 25%    17.500000
# 50%    23.000000
# 75%    33.500000
# max    44.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      int64
# dtypes: int64(1)
# memory usage: 156.0 bytes

# %%
type(df1[0][2])
# Out:
# numpy.int64

# %%
df1
# Out:
#     0
# 0  12
# 1  23
# 2  44

# %%
import pandas as pd
df = pd.DataFrame({"X":[12,23,45,26],"Y":[14,25,36,16]})
df1 = pd.DataFrame({"X":[22,33,44],"Y":[12,21,36],"Z":[12,23,89]})

# %%
df
# Out:
#     X   Y
# 0  12  14
# 1  23  25
# 2  45  36
# 3  26  16

# %%
df1
# Out:
#     X   Y   Z
# 0  22  12  12
# 1  33  21  23
# 2  44  36  89

# %%
df.append(df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8212\202388049.py in ?()
# ----> 1 df.append(df1)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df2 = pd.concat([df,df1])

# %%
df2
# Out:
#     X   Y     Z
# 0  12  14   NaN
# 1  23  25   NaN
# 2  45  36   NaN
# 3  26  16   NaN
# 0  22  12  12.0
# 1  33  21  23.0
# 2  44  36  89.0

# %%
df2 = pd.concat([df,df1],ignore_index=True)

# %%
df2
# Out:
#     X   Y     Z
# 0  12  14   NaN
# 1  23  25   NaN
# 2  45  36   NaN
# 3  26  16   NaN
# 4  22  12  12.0
# 5  33  21  23.0
# 6  44  36  89.0

# %%
import pandas as pd
df4 = pd.DataFrame([[4,5]]*4,columns=["P","Q"])

# %%
df4
# Out:
#    P  Q
# 0  4  5
# 1  4  5
# 2  4  5
# 3  4  5

# %%
df4.apply(np.sqrt)
# Out:
#      P         Q
# 0  2.0  2.236068
# 1  2.0  2.236068
# 2  2.0  2.236068
# 3  2.0  2.236068

# %%
df4.apply(np.max)
# Out:
# P    4
# Q    5
# dtype: int64

# %%
df4.apply(np.max,axis=0)
# Out:
# P    4
# Q    5
# dtype: int64

# %%
df4.apply(np.max,axis=1)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
df4
# Out:
#    P  Q
# 0  4  5
# 1  4  5
# 2  4  5
# 3  4  5

# %%
df4["Z"] = df4["P"].apply(lambda x:6-x)

# %%
df4
# Out:
#    P  Q  Z
# 0  4  5  2
# 1  4  5  2
# 2  4  5  2
# 3  4  5  2

# %%
import pandas as pd
df5 = pd.DataFrame([[45,55,66],[77,88,99],[11,12,13],[np.nan,np.nan,np.nan]],columns=["X","Y","Z"])

# %%
df5
# Out:
#       X     Y     Z
# 0  45.0  55.0  66.0
# 1  77.0  88.0  99.0
# 2  11.0  12.0  13.0
# 3   NaN   NaN   NaN

# %%
df5.aggregate("sum")
# Out:
# X    133.0
# Y    155.0
# Z    178.0
# dtype: float64

# %%
df5.aggregate(["sum","min"])
# Out:
#          X      Y      Z
# sum  133.0  155.0  178.0
# min   11.0   12.0   13.0

# %%
df5.aggregate(["sum","max","min"])
# Out:
#          X      Y      Z
# sum  133.0  155.0  178.0
# max   77.0   88.0   99.0
# min   11.0   12.0   13.0

# %%
df5.aggregate({"X":["sum","max"],"Y":["min","max"]})
# Out:
#          X     Y
# sum  133.0   NaN
# max   77.0  88.0
# min    NaN  12.0

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df["ID"] = [101,102,103,104,105]

# %%
df
# Out:
#     ID
# 0  101
# 1  102
# 2  103
# 3  104
# 4  105

# %%
df.assign(Name=["Surendra","Vibhour","Rohit","Mitali","saloni"])
# Out:
#     ID      Name
# 0  101  Surendra
# 1  102   Vibhour
# 2  103     Rohit
# 3  104    Mitali
# 4  105    saloni

# %%
df
# Out:
#     ID
# 0  101
# 1  102
# 2  103
# 3  104
# 4  105

# %%
df = df.assign(Name=["Surendrs","Vibhour","rohit","Mitali","Saloni"])

# %%
df
# Out:
#     ID      Name
# 0  101  Surendrs
# 1  102   Vibhour
# 2  103     rohit
# 3  104    Mitali
# 4  105    Saloni

# %%
df = df.assign(DOB=[1995,2006,2004,2004,1998])

# %%
df.assign(age=df["DOB"].apply(lambda x:2024-x))
# Out:
#     ID      Name   DOB  age
# 0  101  Surendrs  1995   29
# 1  102   Vibhour  2006   18
# 2  103     rohit  2004   20
# 3  104    Mitali  2004   20
# 4  105    Saloni  1998   26

# %%
df.assign(ab=lambda x:2024-df["DOB"])
# Out:
#     ID      Name   DOB  ab
# 0  101  Surendrs  1995  29
# 1  102   Vibhour  2006  18
# 2  103     rohit  2004  20
# 3  104    Mitali  2004  20
# 4  105    Saloni  1998  26

# %%
df
# Out:
#     ID      Name   DOB
# 0  101  Surendrs  1995
# 1  102   Vibhour  2006
# 2  103     rohit  2004
# 3  104    Mitali  2004
# 4  105    Saloni  1998

# %%
df.describe()
# Out:
#                ID          DOB
# count    5.000000     5.000000
# mean   103.000000  2001.400000
# std      1.581139     4.669047
# min    101.000000  1995.000000
# 25%    102.000000  1998.000000
# 50%    103.000000  2004.000000
# 75%    104.000000  2004.000000
# max    105.000000  2006.000000

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({"Name":["Surendra","Vibhour","Rohit","Mitali"],"Age":[25,18,19,19]})

# %%
df
# Out:
#        Name  Age
# 0  Surendra   25
# 1   Vibhour   18
# 2     Rohit   19
# 3    Mitali   19

# %%
df.count()
# Out:
# Name    4
# Age     4
# dtype: int64

# %%
df.count(axis="columns")
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# dtype: int64

# %%
import pandas as pd 
df = pd.DataFrame({"Name":["Surendra","Vibhour","Rohit","Mitali","Rohit"],"Course":["Python","Java","CCNA","R","CCNA"]})

# %%
df
# Out:
#        Name  Course
# 0  Surendra  Python
# 1   Vibhour    Java
# 2     Rohit    CCNA
# 3    Mitali       R
# 4     Rohit    CCNA

# %%
df.drop_duplicates()
# Out:
#        Name  Course
# 0  Surendra  Python
# 1   Vibhour    Java
# 2     Rohit    CCNA
# 3    Mitali       R

# %%
df
# Out:
#        Name  Course
# 0  Surendra  Python
# 1   Vibhour    Java
# 2     Rohit    CCNA
# 3    Mitali       R
# 4     Rohit    CCNA

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({"Name":["Surendra","Anand","Vibhour","Rohit","Mitali","Parul"],"Percentage":[67,88,88,70,96,96],"Course":["Python","Java","CCNA","R","CCNA","Python"]})

# %%
df
# Out:
#        Name  Percentage  Course
# 0  Surendra          67  Python
# 1     Anand          88    Java
# 2   Vibhour          88    CCNA
# 3     Rohit          70       R
# 4    Mitali          96    CCNA
# 5     Parul          96  Python

# %%
grouped = df.groupby("Course")

# %%
grouped

# %%
grouped["Percentage"].agg(np.mean)
# Out:
# C:\Users\parul\AppData\Local\Temp\ipykernel_8212\1735864269.py:1: FutureWarning: The provided callable <function mean at 0x0000017778C22D40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped["Percentage"].agg(np.mean)
# Course
# CCNA      92.0
# Java      88.0
# Python    81.5
# R         70.0
# Name: Percentage, dtype: float64

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({"Name":["Surendra","Vibhour","Mitali","Parul","Rohit","Meenal","Sam","Sumit","Rakesh","Rekha"],"Percentage":[67,88,88,70,96,96,78,89,98,97],"Course":["Python","Java","CCNA","R","CCNA","Python","Java","CCNA","R","CCNA"]})

# %%
df
# Out:
#        Name  Percentage  Course
# 0  Surendra          67  Python
# 1   Vibhour          88    Java
# 2    Mitali          88    CCNA
# 3     Parul          70       R
# 4     Rohit          96    CCNA
# 5    Meenal          96  Python
# 6       Sam          78    Java
# 7     Sumit          89    CCNA
# 8    Rakesh          98       R
# 9     Rekha          97    CCNA

# %%
grouped=df.groupby("Course")

# %%
grouped["Percentage"].agg(np.mean)
# Out:
# C:\Users\parul\AppData\Local\Temp\ipykernel_8212\1735864269.py:1: FutureWarning: The provided callable <function mean at 0x0000017778C22D40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped["Percentage"].agg(np.mean)
# Course
# CCNA      92.5
# Java      83.0
# Python    81.5
# R         84.0
# Name: Percentage, dtype: float64

# %%
grouped["Percentage"].agg(np.max)
# Out:
# C:\Users\parul\AppData\Local\Temp\ipykernel_8212\3259169289.py:1: FutureWarning: The provided callable <function max at 0x0000017778C22340> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped["Percentage"].agg(np.max)
# Course
# CCNA      97
# Java      88
# Python    96
# R         98
# Name: Percentage, dtype: int64

# %%
grouped["Percentage"].agg(pd.value_counts)
# Out:
# C:\Users\parul\AppData\Local\Temp\ipykernel_8212\3038267026.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   grouped["Percentage"].agg(pd.value_counts)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 grouped["Percentage"].agg(pd.value_counts)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:292, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     289     return self._python_agg_general(func, *args, **kwargs)
#     291 try:
# --> 292     return self._python_agg_general(func, *args, **kwargs)
#     293 except KeyError:
#     294     # KeyError raised in test_groupby.test_basic is bc the func does
#     295     #  a dictionary lookup on group.name, but group name is not
# ...

# %%
grouped["Percentage"].agg(pd.value_counts)
# Out:
# C:\Users\parul\AppData\Local\Temp\ipykernel_8212\3038267026.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   grouped["Percentage"].agg(pd.value_counts)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 grouped["Percentage"].agg(pd.value_counts)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:292, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     289     return self._python_agg_general(func, *args, **kwargs)
#     291 try:
# --> 292     return self._python_agg_general(func, *args, **kwargs)
#     293 except KeyError:
#     294     # KeyError raised in test_groupby.test_basic is bc the func does
#     295     #  a dictionary lookup on group.name, but group name is not
# ...

# %%
grouped["Percentage"].agg(np.count_nonzero)
# Out:
# Course
# CCNA      4
# Java      2
# Python    2
# R         2
# Name: Percentage, dtype: int64

# %%
grouped["Percentage"].agg(np.count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 grouped["Percentage"].agg(np.count)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\__init__.py:347, in __getattr__(attr)
#     344     "Removed in NumPy 1.25.0"
#     345     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 347 raise AttributeError("module {!r} has no attribute "
#     348                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'count'

# %%
sum(grouped["Percentage"].agg(np.count_nonzero))
# Out:
# 10

# %%
df
# Out:
#        Name  Percentage  Course
# 0  Surendra          67  Python
# 1   Vibhour          88    Java
# 2    Mitali          88    CCNA
# 3     Parul          70       R
# 4     Rohit          96    CCNA
# 5    Meenal          96  Python
# 6       Sam          78    Java
# 7     Sumit          89    CCNA
# 8    Rakesh          98       R
# 9     Rekha          97    CCNA

# %%
grouped["Percentage"].agg(np.average)
# Out:
# Course
# CCNA      92.5
# Java      83.0
# Python    81.5
# R         84.0
# Name: Percentage, dtype: float64

# %%
df
# Out:
#        Name  Percentage  Course
# 0  Surendra          67  Python
# 1   Vibhour          88    Java
# 2    Mitali          88    CCNA
# 3     Parul          70       R
# 4     Rohit          96    CCNA
# 5    Meenal          96  Python
# 6       Sam          78    Java
# 7     Sumit          89    CCNA
# 8    Rakesh          98       R
# 9     Rekha          97    CCNA

# %%
for row_index,row in df.iterrows():
    print(row_index,row)
    print()
# Out:
# 0 Name          Surendra
# Percentage          67
# Course          Python
# Name: 0, dtype: object
#
# 1 Name          Vibhour
# Percentage         88
# Course           Java
# Name: 1, dtype: object
#
# 2 Name          Mitali
# Percentage        88
# Course          CCNA
# Name: 2, dtype: object
#
# 3 Name          Parul
# Percentage       70
# Course            R
# Name: 3, dtype: object
#
# 4 Name          Rohit
# Percentage       96
# Course         CCNA
# Name: 4, dtype: object
#
# 5 Name          Meenal
# Percentage        96
# Course        Python
# Name: 5, dtype: object
#
# 6 Name           Sam
# Percentage      78
# Course        Java
# Name: 6, dtype: object
#
# 7 Name          Sumit
# Percentage       89
# Course         CCNA
# Name: 7, dtype: object
#
# 8 Name          Rakesh
# Percentage        98
# Course             R
# Name: 8, dtype: object
#
# 9 Name          Rekha
# Percentage       97
# Course         CCNA
# Name: 9, dtype: object

# %%
for i,j in df.iterrows():
    print(i,j)
    print()
# Out:
# 0 Name          Surendra
# Percentage          67
# Course          Python
# Name: 0, dtype: object
#
# 1 Name          Vibhour
# Percentage         88
# Course           Java
# Name: 1, dtype: object
#
# 2 Name          Mitali
# Percentage        88
# Course          CCNA
# Name: 2, dtype: object
#
# 3 Name          Parul
# Percentage       70
# Course            R
# Name: 3, dtype: object
#
# 4 Name          Rohit
# Percentage       96
# Course         CCNA
# Name: 4, dtype: object
#
# 5 Name          Meenal
# Percentage        96
# Course        Python
# Name: 5, dtype: object
#
# 6 Name           Sam
# Percentage      78
# Course        Java
# Name: 6, dtype: object
#
# 7 Name          Sumit
# Percentage       89
# Course         CCNA
# Name: 7, dtype: object
#
# 8 Name          Rakesh
# Percentage        98
# Course             R
# Name: 8, dtype: object
#
# 9 Name          Rekha
# Percentage       97
# Course         CCNA
# Name: 9, dtype: object

# %%
for i,j in df.items():
    print(i,j)
    print()
# Out:
# Name 0    Surendra
# 1     Vibhour
# 2      Mitali
# 3       Parul
# 4       Rohit
# 5      Meenal
# 6         Sam
# 7       Sumit
# 8      Rakesh
# 9       Rekha
# Name: Name, dtype: object
#
# Percentage 0    67
# 1    88
# 2    88
# 3    70
# 4    96
# 5    96
# 6    78
# 7    89
# 8    98
# 9    97
# Name: Percentage, dtype: int64
#
# Course 0    Python
# 1      Java
# 2      CCNA
# 3         R
# 4      CCNA
# 5    Python
# 6      Java
# 7      CCNA
# 8         R
# 9      CCNA
# Name: Course, dtype: object

# %%
for i in df.itertuples():
    print(i)
    print()
# Out:
# Pandas(Index=0, Name='Surendra', Percentage=67, Course='Python')
#
# Pandas(Index=1, Name='Vibhour', Percentage=88, Course='Java')
#
# Pandas(Index=2, Name='Mitali', Percentage=88, Course='CCNA')
#
# Pandas(Index=3, Name='Parul', Percentage=70, Course='R')
#
# Pandas(Index=4, Name='Rohit', Percentage=96, Course='CCNA')
#
# Pandas(Index=5, Name='Meenal', Percentage=96, Course='Python')
#
# Pandas(Index=6, Name='Sam', Percentage=78, Course='Java')
#
# Pandas(Index=7, Name='Sumit', Percentage=89, Course='CCNA')
#
# Pandas(Index=8, Name='Rakesh', Percentage=98, Course='R')
#
# Pandas(Index=9, Name='Rekha', Percentage=97, Course='CCNA')

# %%
import pandas as pd
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_highest_grossing_Indian_films")

# %%
df = df[0]

# %%
df
# Out:
#     Rank                            Title        Worldwide gross  \
# 0      1                           Dangal        ₹2,023.81 crore
# 1      2      Baahubali 2: The Conclusion       ₹1,810.595 crore
# 2      3                              RRR        ₹1,387.26 crore
# 3      4                   KGF: Chapter 2     ₹1,200–1,250 crore
# 4      5                            Jawan        ₹1,148.32 crore
# 5      6                          Pathaan         ₹1,050.3 crore
# 6      7                Bajrangi Bhaijaan   ₹918.18–969.06 crore
# 7      8                           Animal          ₹917.82 crore
# 8      9                 Secret Superstar    ₹875.78–905.7 crore
# 9     10                               PK  ₹750.595–769.89 crore
# 10    11       Salaar: Part 1 – Ceasefire         ₹705–715 crore
# 11    12                              2.0          ₹699.89 crore
# 12    13                          Gadar 2          ₹691.08 crore
# ...

# %%
df.head(3)
# Out:
#    Rank                        Title   Worldwide gross Primary language(s)  \
# 0     1                       Dangal   ₹2,023.81 crore               Hindi
# 1     2  Baahubali 2: The Conclusion  ₹1,810.595 crore        Telugu Tamil
# 2     3                          RRR   ₹1,387.26 crore              Telugu
#
#    Year              Ref.
# 0  2016              [11]
# 1  2017  [12][13][14][11]
# 2  2022           [a][16]

# %%
df[0:40:10]
# Out:
#     Rank                       Title       Worldwide gross  \
# 0      1                      Dangal       ₹2,023.81 crore
# 10    11  Salaar: Part 1 – Ceasefire        ₹705–715 crore
# 20    21                     Dhoom 3         ₹556.74 crore
# 30    31                    3 Idiots  ₹397.08–400.61 crore
#
#    Primary language(s)  Year          Ref.
# 0                Hindi  2016          [11]
# 10              Telugu  2023      [36][37]
# 20               Hindi  2013          [50]
# 30               Hindi  2009  [11][30][66]

# %%
df.iloc[0:40:10,0:5:2]
# Out:
#     Rank       Worldwide gross  Year
# 0      1       ₹2,023.81 crore  2016
# 10    11        ₹705–715 crore  2023
# 20    21         ₹556.74 crore  2013
# 30    31  ₹397.08–400.61 crore  2009

# %%
df.loc[0:40:10,0:5:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[233], line 1
# ----> 1 df.loc[0:40:10,0:5:2]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1339, in _LocIndexer._getitem_tuple(self, tup)
#    1336 if self._multi_take_opportunity(tup):
#    1337     return self._multi_take(tup)
# -> 1339 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.head(4)
# Out:
#    Rank                        Title     Worldwide gross Primary language(s)  \
# 0     1                       Dangal     ₹2,023.81 crore               Hindi
# 1     2  Baahubali 2: The Conclusion    ₹1,810.595 crore        Telugu Tamil
# 2     3                          RRR     ₹1,387.26 crore              Telugu
# 3     4               KGF: Chapter 2  ₹1,200–1,250 crore             Kannada
#
#    Year              Ref.
# 0  2016              [11]
# 1  2017  [12][13][14][11]
# 2  2022           [a][16]
# 3  2022               [b]

# %%
df.loc[0:20:2,["Rank","Title","Year"]]
# Out:
#     Rank                       Title  Year
# 0      1                      Dangal  2016
# 2      3                         RRR  2022
# 4      5                       Jawan  2023
# 6      7           Bajrangi Bhaijaan  2015
# 8      9            Secret Superstar  2017
# 10    11  Salaar: Part 1 – Ceasefire  2023
# 12    13                     Gadar 2  2023
# 14    15                      Jailer  2023
# 16    17    Baahubali: The Beginning  2015
# 18    19                   Padmaavat  2018
# 20    21                     Dhoom 3  2013

# %%
df = pd.read_html("https://www.cricbuzz.com/cricket.series/7607//indian_premier_league_2024/stats")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 df = pd.read_html("https://www.cricbuzz.com/cricket.series/7607//indian_premier_league_2024/stats")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
#    1231         is_file_like(io),
#    (...)
#    1235     ]
#    1236 ):
#    1237     warnings.warn(
#    1238         "Passing literal html to 'read_html' is deprecated and "
#    1239         "will be removed in a future version. To read from a "
#    (...)
#    1242         stacklevel=find_stack_level(),
#    1243     )
# -> 1245 return _parse(
# ...

# %%
df
# Out:
#     Rank                            Title        Worldwide gross  \
# 0      1                           Dangal        ₹2,023.81 crore
# 1      2      Baahubali 2: The Conclusion       ₹1,810.595 crore
# 2      3                              RRR        ₹1,387.26 crore
# 3      4                   KGF: Chapter 2     ₹1,200–1,250 crore
# 4      5                            Jawan        ₹1,148.32 crore
# 5      6                          Pathaan         ₹1,050.3 crore
# 6      7                Bajrangi Bhaijaan   ₹918.18–969.06 crore
# 7      8                           Animal          ₹917.82 crore
# 8      9                 Secret Superstar    ₹875.78–905.7 crore
# 9     10                               PK  ₹750.595–769.89 crore
# 10    11       Salaar: Part 1 – Ceasefire         ₹705–715 crore
# 11    12                              2.0          ₹699.89 crore
# 12    13                          Gadar 2          ₹691.08 crore
# ...

# %%
df.describe()
# Out:
#             Rank         Year
# count  50.000000    50.000000
# mean   25.480000  2019.100000
# std    14.549339     3.823931
# min     1.000000  2009.000000
# 25%    13.250000  2016.000000
# 50%    25.500000  2019.000000
# 75%    37.750000  2023.000000
# max    50.000000  2024.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 50 non-null     int64
#  1   Title                50 non-null     object
#  2   Worldwide gross      50 non-null     object
#  3   Primary language(s)  50 non-null     object
#  4   Year                 50 non-null     int64
#  5   Ref.                 50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB

# %%
#  Styling the database "X" as highlight_max and color it as red:-

x.style.highlight_max(color="red",axis=0)
# Out:
# <style type="text/css">
# #T_7d8fd_row3_col3, #T_7d8fd_row4_col5, #T_7d8fd_row13_col4, #T_7d8fd_row15_col4, #T_7d8fd_row16_col1, #T_7d8fd_row18_col1, #T_7d8fd_row48_col2, #T_7d8fd_row49_col0 {
#   background-color: red;
# }
# </style>
# <table id="T_7d8fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d8fd_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_7d8fd_level0_col1" class="col_heading level0 col1" >Peak</th>
#       <th id="T_7d8fd_level0_col2" class="col_heading level0 col2" >Title</th>
#       <th id="T_7d8fd_level0_col3" class="col_heading level0 col3" >Worldwide gross</th>
#       <th id="T_7d8fd_level0_col4" class="col_heading level0 col4" >Year</th>
#       <th id="T_7d8fd_level0_col5" class="col_heading level0 col5" >Ref</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d8fd_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# Setting background color as gradient color as cmap="Spectral":-

x.style.background_gradient(cmap="Spectral")
# Out:
# <style type="text/css">
# #T_9782a_row0_col0, #T_9782a_row44_col4 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_9782a_row0_col4 {
#   background-color: #f7fcb2;
#   color: #000000;
# }
# #T_9782a_row1_col0 {
#   background-color: #a90d45;
#   color: #f1f1f1;
# }
# #T_9782a_row1_col4, #T_9782a_row8_col4, #T_9782a_row12_col4, #T_9782a_row29_col4, #T_9782a_row30_col4, #T_9782a_row35_col4, #T_9782a_row36_col4, #T_9782a_row37_col4, #T_9782a_row41_col4 {
#   background-color: #439bb5;
#   color: #f1f1f1;
# }
# #T_9782a_row2_col0 {
#   background-color: #b41947;
#   color: #f1f1f1;
# }
# #T_9782a_row2_col4, #T_9782a_row11_col4 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_9782a_row3_col0 {
#   background-color: #be254a;
#   color: #f1f1f1;
# }
# #T_9782a_row3_col4 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_9782a_row4_col0 {
#   background-color: #c9314c;
#   color: #f1f1f1;
# }
# ...

# %%
# Making a def function as row_style :-
# Creating a If-Else condition:-
# If the year is less than "2015" than color the row as "pink":-
# Else color the rest year as "purple":-
# At the end style the database as "apply" at axix=1 or row:-

def row_style(row):
    if row.Year < 2015:
        return pd.Series('background-color: pink', row.index)
    else:
        return pd.Series('background-color: purple', row.index)

x.style.apply(row_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
# Making a def function as column_style :-
# Creating a If-Else condition:-
# If the year is less than "2015" than color the column as "purple":-
# Else color the rest year as "orange":-
# At the end style the database as "apply" at axix=1 or column:-

def column_style(column):
    if column.Year < 2015:
        return pd.Series('background-color: purple', column.index)
    else:
        return pd.Series('background-color: orange', column.index)

x.style.apply(column_style, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
# Styling the background-gradiant as green through the "set-precision":-

y=x.style.background_gradient("Greens").set_precision(2).highlight_null('black').highlight_min(axis=0, color='red').highlight_max(axis=0, color='pink')
y

# Here the "set-precision" module is not working.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 y=x.style.background_gradient("Greens").set_precision(2).highlight_null('black').highlight_min(axis=0, color='red').highlight_max(axis=0, color='pink')
#       2 y
#
# AttributeError: 'Styler' object has no attribute 'set_precision'

# %%
# Styling the head as highlight_min in the"purple" color:-

x.head().style.highlight_min(color='purple',axis=0)
# Out:
# <style type="text/css">
# #T_88b38_row0_col0, #T_88b38_row0_col1, #T_88b38_row0_col2, #T_88b38_row0_col5, #T_88b38_row1_col1, #T_88b38_row3_col1, #T_88b38_row3_col4, #T_88b38_row4_col3 {
#   background-color: purple;
# }
# </style>
# <table id="T_88b38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88b38_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_88b38_level0_col1" class="col_heading level0 col1" >Peak</th>
#       <th id="T_88b38_level0_col2" class="col_heading level0 col2" >Title</th>
#       <th id="T_88b38_level0_col3" class="col_heading level0 col3" >Worldwide gross</th>
#       <th id="T_88b38_level0_col4" class="col_heading level0 col4" >Year</th>
#       <th id="T_88b38_level0_col5" class="col_heading level0 col5" >Ref</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88b38_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
y=x.head().style.background_gradient("Greens").set_precision(2).highlight_null('black').highlight_min(axis=0, color='red').highlight_max(axis=0, color='pink')
y

# Here the"set-precision" module is not working.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 y=x.head().style.background_gradient("Greens").set_precision(2).highlight_null('black').highlight_min(axis=0, color='red').highlight_max(axis=0, color='pink')
#       2 y
#
# AttributeError: 'Styler' object has no attribute 'set_precision'
