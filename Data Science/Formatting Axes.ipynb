# %% [markdown]
# # Formatting Axes :-

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,axes = plt.subplots(1,2,figsize=(10,4))
x = np.arange(1,5)
axes[0].plot(x,np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal Scale")
axes[1].plot(x,x**2)
axes[1].set_yscale("Log")
axes[1].set_title("Log Scale (Y)")
axes[0].set_xlabel("X - Axis")
axes[0].set_ylabel("Y - Axis")
axes[0].xaxis.labelpad=10
axes[1].set_xlabel("X - Axis")
axes[1].set_ylabel("Y - Axis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 9
#       7 axes[0].set_title("Normal Scale")
#       8 axes[1].plot(x,x**2)
# ----> 9 axes[1].set_yscale("Log")
#      10 axes[1].set_title("Log Scale (Y)")
#      11 axes[0].set_xlabel("X - Axis")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:837, in Axis._set_axes_scale(self, value, **kwargs)
#     834 old_default_lims = (self.get_major_locator()
#     835                     .nonsingular(-np.inf, np.inf))
#     836 for ax in self._get_shared_axes():
# --> 837     ax._axis_map[name]._set_scale(value, **kwargs)
#     838     ax._update_transScale()
#     839     ax.stale = True
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:796, in Axis._set_scale(self, value, **kwargs)
#     794 def _set_scale(self, value, **kwargs):
#     795     if not isinstance(value, mscale.ScaleBase):
# --> 796         self._scale = mscale.scale_factory(value, self, **kwargs)
#     797     else:
#     798         self._scale = value
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py:716, in scale_factory(scale, axis, **kwargs)
#     707 def scale_factory(scale, axis, **kwargs):
#     708     """
#     709     Return a scale class by name.
#     710
#    (...)
#     714     axis : `~matplotlib.axis.Axis`
#     715     """
# --> 716     scale_cls = _api.check_getitem(_scale_mapping, scale=scale)
#     717     return scale_cls(axis, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:183, in check_getitem(mapping, **kwargs)
#     181     return mapping[v]
#     182 except KeyError:
# --> 183     raise ValueError(
#     184         f"{v!r} is not a valid value for {k}; supported values are "
#     185         f"{', '.join(map(repr, mapping))}") from None
#
# ValueError: 'Log' is not a valid value for scale; supported values are 'linear', 'log', 'symlog', 'asinh', 'logit', 'function', 'functionlog'

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,axes = plt.subplots(1,2,figsize=(10,4))
x = np.arange(1,5)
axes[0].plot(x,np.exp(x))
axes[0].plot(x,x**2)
axes[0].set_title("Normal Scale")
axes[1].plot(x,x**2)
axes[1].plot(x,np.exp(x))
axes[1].set_yscale("Log")
axes[1].set_title("Log Scale (Y)")
axes[0].set_xlabel("X - Axis")
axes[0].set_ylabel("Y - Axis")
axes[0].xaxis.labelpad=10
axes[1].set_xlabel("X - Axis")
axes[1].set_ylabel("Y - Axis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 10
#       8 axes[1].plot(x,x**2)
#       9 axes[1].plot(x,np.exp(x))
# ---> 10 axes[1].set_yscale("Log")
#      11 axes[1].set_title("Log Scale (Y)")
#      12 axes[0].set_xlabel("X - Axis")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:837, in Axis._set_axes_scale(self, value, **kwargs)
#     834 old_default_lims = (self.get_major_locator()
#     835                     .nonsingular(-np.inf, np.inf))
#     836 for ax in self._get_shared_axes():
# --> 837     ax._axis_map[name]._set_scale(value, **kwargs)
#     838     ax._update_transScale()
#     839     ax.stale = True
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:796, in Axis._set_scale(self, value, **kwargs)
#     794 def _set_scale(self, value, **kwargs):
#     795     if not isinstance(value, mscale.ScaleBase):
# --> 796         self._scale = mscale.scale_factory(value, self, **kwargs)
#     797     else:
#     798         self._scale = value
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\scale.py:716, in scale_factory(scale, axis, **kwargs)
#     707 def scale_factory(scale, axis, **kwargs):
#     708     """
#     709     Return a scale class by name.
#     710
#    (...)
#     714     axis : `~matplotlib.axis.Axis`
#     715     """
# --> 716     scale_cls = _api.check_getitem(_scale_mapping, scale=scale)
#     717     return scale_cls(axis, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:183, in check_getitem(mapping, **kwargs)
#     181     return mapping[v]
#     182 except KeyError:
# --> 183     raise ValueError(
#     184         f"{v!r} is not a valid value for {k}; supported values are "
#     185         f"{', '.join(map(repr, mapping))}") from None
#
# ValueError: 'Log' is not a valid value for scale; supported values are 'linear', 'log', 'symlog', 'asinh', 'logit', 'function', 'functionlog'

# %%
### spine :

  ###

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.spines["bottom"].set_color("g")
ax.spines["left"].set_color("r")
ax.spines["left"].set_linewidth(4)
ax.spines["right"].set_color(None)
ax.spines["top"].set_color(None)
ax.plot([1,2,3,4,5])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.spines["bottom"].set_color("g")
ax.spines["left"].set_color("r")
ax.spines["left"].set_linewidth(4)
ax.spines["right"].set_color("r")
ax.spines["top"].set_color("g")
ax.plot([1,2,3,4,5])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.spines["bottom"].set_color("g")
ax.spines["bottom"].set_linewidth(4)
ax.spines["left"].set_color("r")
ax.spines["left"].set_linewidth(4)
ax.spines["right"].set_color("r")
ax.spines["right"].set_linewidth(4)
ax.spines["top"].set_color("g")
ax.spines["top"].set_linewidth(4)
ax.plot([1,2,3,4,5])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.spines["bottom"].set_color("g")
ax.spines["bottom"].set_linewidth(4)
ax.spines["left"].set_color("r")
ax.spines["left"].set_linewidth(4)
ax.spines["right"].set_color("r")
ax.spines["right"].set_linewidth(4)
ax.spines["top"].set_color("g")
ax.spines["top"].set_linewidth(4)
ax.plot()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.spines["bottom"].set_color("g")
ax.spines["bottom"].set_linewidth(4)
ax.spines["left"].set_color("r")
ax.spines["left"].set_linewidth(4)
ax.spines["right"].set_color("r")
ax.spines["right"].set_linewidth(4)
ax.spines["top"].set_color("g")
ax.spines["top"].set_linewidth(4)
x = np.arange(0,np.pi*2,0.05)
ax.plot(x,np.sin(x),"orange")
plt.show()
