# %% [markdown]
# # Subplots :-

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,ax = plt.subplots(2,2)
x = np.linspace(0,8,1000)

ax[0,0].plot(x,np.sin(x),'c--')
ax[0,1].plot(x,np.cos(x),'g')
ax[1,0].plot(x,np.tan(x),'orange')
ax[1,1].plot(x,np.log(x),'r')
fig.show()
# Out:
# C:\Users\parul\AppData\Local\Temp\ipykernel_2128\3646331634.py:9: RuntimeWarning: divide by zero encountered in log
#   ax[1,1].plot(x,np.log(x),'r')
# C:\Users\parul\AppData\Local\Temp\ipykernel_2128\3646331634.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
